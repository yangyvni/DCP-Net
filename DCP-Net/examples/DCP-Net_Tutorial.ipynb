# %% [markdown]
#  ## Setup the Environment
#  ### 1. Required environments:
# * Linux
# * Python 3.9
# * PyTorch 1.12.1
# * CUDA 11.3
# * GCC 5+
#
# ### 2. Installation:
#
# Note that our DCP-Net is based on the [YOLO11](https://github.com/ultralytics/ultralytics). Assume that your environment has satisfied the above requirements, please follow the following steps for installation.
#
# ```shell script
# # setup_env.sh
# conda env create -f environment.yaml
# conda activate dcpnet
#
# pip install -r requirements.txt
# ```
#
# ### 3. Environment Checking:

# %%
import torch
import os
import ultralytics

ultralytics.checks()
print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# Ultralytics 8.3.182 🚀 Python-3.9.25 torch-1.12.1+cu113 CUDA:0 (NVIDIA RTX A6000, 48677MiB)
# Setup complete ✅ (128 CPUs, 503.5 GB RAM, 37.7/186.7 GB disk)
# 1.12.1+cu113
# True

# %% [markdown]
# ## Prepare Dataset:
# Download [AI-TODv2](https://drive.google.com/drive/folders/1Er14atDO1cBraBD4DSFODZV1x7NHO_PY?usp=sharing) dataset; Download [DOTA-v1.0](https://captain-whu.github.io/DOTA/dataset.html) dataset.
#
# ### 1. AI-TODv2 Introduction:

# %%
# !cat ../ultralytics/cfg/datasets/dataset.yaml

# %% [markdown]
# ### 2. DOTA-v1.0 Introduction:

# %%
# !cat ../ultralytics/cfg/datasets/dataset_dota.yaml

# %% [markdown]
# ## Train, Test, and Predict
#
# ### 1. Train

# %%
# !python ../train.py

# %% [markdown]
# ### 2.Test

# %%
# !python ../test.py

# %% [markdown]
# ### 3. Predict

# %%
# !python ../predict.py
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
# The DISPLAY environment variable isn't set.
#
# image 1/1 /data/jiayaxin/proj/research/DQ-DETR-main/DQ-DETR-main/datasets/Dataset/dota/images/val/P2794_3600_2400.jpg: 640x640 2 large-vehicles, 5 ships, 13 small-vehicles, 19.9ms
# Speed: 7.5ms preprocess, 19.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/test_dota/P2794_3600_2400

# %%
import cv2
import matplotlib.pyplot as plt

# %matplotlib inline

# 图片路径
img_path = 'runs/test_dota/P2794_3600_2400/P2794_3600_2400.jpg'

# 读取
img = cv2.imread(img_path)

# BGR -> RGB
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# 显示
plt.figure(figsize=(8,8))
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# ## Visualization Results
# ### 1. AI-TODv2
#
# ![AI-TODv2](results/AI-TODv2.png)
#
#
# ### 2. DOTA-v1.0
#
# ![DOTA-v1.0](results/DOTA-v1.0.png)
